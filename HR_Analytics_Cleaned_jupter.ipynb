# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:/Users/DELL/Downloads/HR_Analytics_Raw_Dataset.csv")

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30020 entries, 0 to 30019
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          30017 non-null  float64
#  1   Age                 30019 non-null  float64
#  2   Attrition           30017 non-null  object
#  3   BusinessTravel      30016 non-null  object
#  4   Department          30020 non-null  object
#  5   DistanceFromHome    30019 non-null  float64
#  6   Education           30016 non-null  float64
#  7   EducationField      30019 non-null  object
#  8   Gender              30016 non-null  object
#  9   JobLevel            30019 non-null  float64
#  10  JobRole             30019 non-null  object
#  11  MaritalStatus       30018 non-null  object
#  12  MonthlyIncome       30020 non-null  float64
#  13  NumCompaniesWorked  30017 non-null  float64
#  14  OverTime            30018 non-null  object
# ...

# %%
df.tail(30)
# Out:
#        EmployeeID   Age Attrition     BusinessTravel   Department  \
# 29990     20940.0  39.0        No         Non-Travel  Development
# 29991     17569.0  44.0       Yes  Travel_Frequently        Sales
# 29992      6421.0  42.0        No      Travel_Rarely  Development
# 29993      5052.0  40.0        No      Travel_Rarely  Development
# 29994      5312.0  43.0        No      Travel_Rarely           HR
# 29995      2434.0  49.0       Yes  Travel_Frequently  Development
# 29996     23334.0  34.0        No         Non-Travel  Development
# 29997     26968.0  46.0       Yes         Non-Travel        Sales
# 29998       770.0  38.0       Yes         Non-Travel           HR
# 29999      1686.0  57.0        No  Travel_Frequently           HR
# 30000      8323.0  40.0       Yes  Travel_Frequently        Sales
# 30001     16024.0  23.0       Yes      Travel_Rarely        Sales
# 30002     27496.0  52.0       Yes      Travel_Rarely        Sales
# ...

# %%
df.isnull()
# Out:
#        EmployeeID    Age  Attrition  BusinessTravel  Department  \
# 0           False  False      False           False       False
# 1           False  False      False           False       False
# 2           False  False      False           False       False
# 3           False  False      False           False       False
# 4           False  False      False           False       False
# ...           ...    ...        ...             ...         ...
# 30015       False  False      False           False       False
# 30016       False  False      False           False       False
# 30017       False  False      False           False       False
# 30018       False  False      False           False       False
# 30019       False  False      False           False       False
#
#        DistanceFromHome  Education  EducationField  Gender  JobLevel  JobRole  \
# 0                 False      False           False   False     False    False
# ...

# %%
df.head()
# Out:
#    EmployeeID   Age Attrition     BusinessTravel Department  DistanceFromHome  \
# 0     25336.0  26.0        No         Non-Travel      Sales              20.0
# 1     26461.0  48.0       Yes  Travel_Frequently      Sales              22.0
# 2     23905.0  45.0        No      Travel_Rarely         HR               7.0
# 3     23423.0  42.0        No         Non-Travel         HR              29.0
# 4      4606.0  54.0       Yes  Travel_Frequently         HR              25.0
#
#    Education EducationField  Gender  JobLevel             JobRole  \
# 0        2.0      Technical    Male       3.0             Manager
# 1        4.0      Marketing  Female       4.0           Developer
# 2        2.0      Marketing    Male       3.0             Analyst
# 3        3.0  Life Sciences    Male       4.0             Analyst
# 4        2.0          Other  Female       3.0  Research Scientist
#
#   MaritalStatus  MonthlyIncome  NumCompaniesWorked OverTime  YearsAtCompany
# ...

# %%
df['Education']
# Out:
# 0        2.0
# 1        4.0
# 2        2.0
# 3        3.0
# 4        2.0
#         ...
# 30015    2.0
# 30016    2.0
# 30017    3.0
# 30018    2.0
# 30019    2.0
# Name: Education, Length: 30020, dtype: float64

# %%
df[['Department','JobRole']]
# Out:
#         Department               JobRole
# 0            Sales               Manager
# 1            Sales             Developer
# 2               HR               Analyst
# 3               HR               Analyst
# 4               HR    Research Scientist
# ...            ...                   ...
# 30015  Development               Manager
# 30016           HR    Research Scientist
# 30017        Sales  Sales Representative
# 30018  Development  Sales Representative
# 30019           HR               Analyst
#
# [30020 rows x 2 columns]

# %%
df[df['Department']=='HR']
# Out:
#        EmployeeID   Age Attrition     BusinessTravel Department  \
# 2         23905.0  45.0        No      Travel_Rarely         HR
# 3         23423.0  42.0        No         Non-Travel         HR
# 4          4606.0  54.0       Yes  Travel_Frequently         HR
# 5         22263.0  50.0        No         Non-Travel         HR
# 12        24453.0  20.0       Yes  Travel_Frequently         HR
# ...           ...   ...       ...                ...        ...
# 30008     29911.0  49.0       Yes         Non-Travel         HR
# 30009     16851.0  38.0        No         Non-Travel         HR
# 30013     11965.0  41.0        No         Non-Travel         HR
# 30016      5391.0  22.0       Yes  Travel_Frequently         HR
# 30019     23655.0  57.0        No      Travel_Rarely         HR
#
#        DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 2                   7.0        2.0      Marketing    Male       3.0
# ...

# %%
df[df['Age']>30]
# Out:
#        EmployeeID   Age Attrition     BusinessTravel   Department  \
# 1         26461.0  48.0       Yes  Travel_Frequently        Sales
# 2         23905.0  45.0        No      Travel_Rarely           HR
# 3         23423.0  42.0        No         Non-Travel           HR
# 4          4606.0  54.0       Yes  Travel_Frequently           HR
# 5         22263.0  50.0        No         Non-Travel           HR
# ...           ...   ...       ...                ...          ...
# 30013     11965.0  41.0        No         Non-Travel           HR
# 30014     21576.0  57.0        No  Travel_Frequently        Sales
# 30015     29803.0  38.0        No         Non-Travel  Development
# 30018     15796.0  56.0       Yes      Travel_Rarely  Development
# 30019     23655.0  57.0        No      Travel_Rarely           HR
#
#        DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 1                  22.0        4.0      Marketing  Female       4.0
# ...

# %%
df[df['Gender']=='Female']
# Out:
#        EmployeeID   Age Attrition     BusinessTravel   Department  \
# 1         26461.0  48.0       Yes  Travel_Frequently        Sales
# 4          4606.0  54.0       Yes  Travel_Frequently           HR
# 7          4983.0  43.0       Yes      Travel_Rarely        Sales
# 9          3283.0  59.0       Yes         Non-Travel        Sales
# 10        11542.0  24.0        No         Non-Travel        Sales
# ...           ...   ...       ...                ...          ...
# 30008     29911.0  49.0       Yes         Non-Travel           HR
# 30010      6266.0  18.0        No         Non-Travel        Sales
# 30013     11965.0  41.0        No         Non-Travel           HR
# 30014     21576.0  57.0        No  Travel_Frequently        Sales
# 30015     29803.0  38.0        No         Non-Travel  Development
#
#        DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 1                  22.0        4.0      Marketing  Female       4.0
# ...

# %%
df.isnull()
# Out:
#        EmployeeID    Age  Attrition  BusinessTravel  Department  \
# 0           False  False      False           False       False
# 1           False  False      False           False       False
# 2           False  False      False           False       False
# 3           False  False      False           False       False
# 4           False  False      False           False       False
# ...           ...    ...        ...             ...         ...
# 30015       False  False      False           False       False
# 30016       False  False      False           False       False
# 30017       False  False      False           False       False
# 30018       False  False      False           False       False
# 30019       False  False      False           False       False
#
#        DistanceFromHome  Education  EducationField  Gender  JobLevel  JobRole  \
# 0                 False      False           False   False     False    False
# ...

# %%
df=df.dropna()

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df['EmployeeID']=df['EmployeeID'].astype('Int32')

# %%
df['Age']=df['Age'].astype('Int32')

# %%
df['Education']=df['Education'].astype('Int32')

# %%
df['NumCompaniesWorked']=df['NumCompaniesWorked'].astype('Int32')

# %%
df['JobLevel']=df['JobLevel'].astype('Int32')

# %%
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel Department  DistanceFromHome  \
# 0       25336   26        No         Non-Travel      Sales              20.0
# 1       26461   48       Yes  Travel_Frequently      Sales              22.0
# 2       23905   45        No      Travel_Rarely         HR               7.0
# 3       23423   42        No         Non-Travel         HR              29.0
# 4        4606   54       Yes  Travel_Frequently         HR              25.0
#
#    Education EducationField  Gender  JobLevel             JobRole  \
# 0          2      Technical    Male         3             Manager
# 1          4      Marketing  Female         4           Developer
# 2          2      Marketing    Male         3             Analyst
# 3          3  Life Sciences    Male         4             Analyst
# 4          2          Other  Female         3  Research Scientist
#
#   MaritalStatus  MonthlyIncome  NumCompaniesWorked OverTime  YearsAtCompany
# ...

# %%
df.groupby('JobRole')['MonthlyIncome'].sum()
# Out:
# JobRole
# Analyst                 81230685.0
# Developer               80107123.0
# Executive               79657802.0
# Manager                 80193632.0
# Research Scientist      80009299.0
# Sales Representative    80112968.0
# Unknown                    46345.0
# Name: MonthlyIncome, dtype: float64

# %%
df['JobRole'].replace('Unknown', np.nan, inplace=True)
df['JobRole'].fillna(df['JobRole'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\3920102547.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['JobRole'].replace('Unknown', np.nan, inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\3920102547.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['JobRole'].fillna(df['JobRole'].mode()[0],inplace=True)

# %%
df['MaritalStatus'].replace('Unknown', np.nan, inplace=True)
df['MaritalStatus'].fillna(df['MaritalStatus'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\3366326427.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MaritalStatus'].replace('Unknown', np.nan, inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\3366326427.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['OverTime'].replace('Unknown', np.nan, inplace=True)
df['OverTime'].fillna(df['OverTime'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\633941986.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['OverTime'].replace('Unknown', np.nan, inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\633941986.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['EducationField'].replace('Unknown', np.nan, inplace=True)
df['EducationField'].fillna(df['EducationField'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\4248486773.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['EducationField'].replace('Unknown', np.nan, inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\4248486773.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['BusinessTravel'].replace('Unknown', np.nan, inplace=True)
df['BusinessTravel'].fillna(df['BusinessTravel'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\1404130568.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BusinessTravel'].replace('Unknown', np.nan, inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\1404130568.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['Attrition'].replace('Unknown', np.nan, inplace=True)
df['Attrition'].fillna(df['Attrition'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\1376981555.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attrition'].replace('Unknown', np.nan, inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\1376981555.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['Gender'].replace('Unknown', np.nan, inplace=True)
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\2853170559.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace('Unknown', np.nan, inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\2853170559.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     15125
# Yes    14865
# Name: count, dtype: int64

# %%
df['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        10079
# Travel_Frequently    10021
# Non-Travel            9890
# Name: count, dtype: int64

# %%
df.sort_values('NumCompaniesWorked')
# Out:
#        EmployeeID  Age Attrition     BusinessTravel   Department  \
# 3029        10549   18       Yes      Travel_Rarely        Sales
# 26876        4532   30        No  Travel_Frequently           HR
# 26867        5440   37       Yes         Non-Travel        Sales
# 26853       18212   22       Yes         Non-Travel        Sales
# 3052        14042   27        No  Travel_Frequently  Development
# ...           ...  ...       ...                ...          ...
# 5829        12112   46        No         Non-Travel        Sales
# 5821        12532   27        No         Non-Travel  Development
# 24121       23359   53        No  Travel_Frequently           HR
# 24081       22524   31       Yes         Non-Travel        Sales
# 24080       17959   47       Yes      Travel_Rarely        Sales
#
#        DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 3029               21.0          3          Other  Female         4
# ...

# %%
df.sort_values('Age',ascending=True)
# Out:
#        EmployeeID  Age Attrition     BusinessTravel   Department  \
# 29960        8793   18        No  Travel_Frequently  Development
# 29959       10556   18        No      Travel_Rarely        Sales
# 17827       26964   18        No      Travel_Rarely        Sales
# 18118       26085   18       Yes      Travel_Rarely  Development
# 18112       29764   18       Yes      Travel_Rarely           HR
# ...           ...  ...       ...                ...          ...
# 2311          944   59       Yes  Travel_Frequently  Development
# 2326        14282   59       Yes  Travel_Frequently           HR
# 15628       22711   59       Yes      Travel_Rarely        Sales
# 28537       11054   59        No         Non-Travel        Sales
# 15633       21895   59        No  Travel_Frequently  Development
#
#        DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 29960               6.0          1      Marketing  Female         1
# ...

# %%
df.isnull().sum()
# Out:
# EmployeeID            0
# Age                   0
# Attrition             0
# BusinessTravel        0
# Department            0
# DistanceFromHome      0
# Education             0
# EducationField        0
# Gender                0
# JobLevel              0
# JobRole               0
# MaritalStatus         0
# MonthlyIncome         0
# NumCompaniesWorked    0
# OverTime              0
# YearsAtCompany        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
df[df.duplicated()]
# Out:
#        EmployeeID  Age Attrition     BusinessTravel   Department  \
# 2392        14475   49        No      Travel_Rarely           HR
# 6541         2665   41        No      Travel_Rarely  Development
# 6859         2309   35        No  Travel_Frequently  Development
# 7758         5149   44       Yes  Travel_Frequently        Sales
# 12355       14055   22        No      Travel_Rarely  Development
# 13444        8512   33       Yes      Travel_Rarely        Sales
# 13613       23398   46        No         Non-Travel           HR
# 13775       10785   32        No  Travel_Frequently        Sales
# 13895       14981   21       Yes         Non-Travel        Sales
# 14913       14978   46       Yes         Non-Travel           HR
# 16274       19044   27       Yes  Travel_Frequently        Sales
# 17302       15948   26        No         Non-Travel        Sales
# 17534       22405   37       Yes  Travel_Frequently        Sales
# ...

# %%
df = df.drop_duplicates(keep=False)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (29950, 16)

# %%
df=df[df['MonthlyIncome']>0]

# %%
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel Department  DistanceFromHome  \
# 0       25336   26        No         Non-Travel      Sales              20.0
# 1       26461   48       Yes  Travel_Frequently      Sales              22.0
# 2       23905   45        No      Travel_Rarely         HR               7.0
# 3       23423   42        No         Non-Travel         HR              29.0
# 4        4606   54       Yes  Travel_Frequently         HR              25.0
#
#    Education EducationField  Gender  JobLevel             JobRole  \
# 0          2      Technical    Male         3             Manager
# 1          4      Marketing  Female         4           Developer
# 2          2      Marketing    Male         3             Analyst
# 3          3  Life Sciences    Male         4             Analyst
# 4          2          Other  Female         3  Research Scientist
#
#   MaritalStatus  MonthlyIncome  NumCompaniesWorked OverTime  YearsAtCompany
# ...

# %%
(df == "Unknown").sum()
# Out:
# EmployeeID            0
# Age                   0
# Attrition             0
# BusinessTravel        0
# Department            0
# DistanceFromHome      0
# Education             0
# EducationField        0
# Gender                0
# JobLevel              0
# JobRole               0
# MaritalStatus         0
# MonthlyIncome         0
# NumCompaniesWorked    0
# OverTime              0
# YearsAtCompany        0
# dtype: Int64

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
cat_cols = [
    'Attrition', 'BusinessTravel', 'Department', 'EducationField',
    'Gender', 'JobRole', 'MaritalStatus', 'OverTime'
]

df[cat_cols] = df[cat_cols].astype('category')

# %%
df.dtypes
# Out:
# EmployeeID               Int32
# Age                      Int32
# Attrition             category
# BusinessTravel        category
# Department            category
# DistanceFromHome       float64
# Education                Int32
# EducationField        category
# Gender                category
# JobLevel                 Int32
# JobRole               category
# MaritalStatus         category
# MonthlyIncome          float64
# NumCompaniesWorked       Int32
# OverTime              category
# YearsAtCompany           int64
# dtype: object

# %%
df.shape
# Out:
# (29950, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29950 entries, 0 to 30019
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          29950 non-null  Int32
#  1   Age                 29950 non-null  Int32
#  2   Attrition           29950 non-null  category
#  3   BusinessTravel      29950 non-null  category
#  4   Department          29950 non-null  category
#  5   DistanceFromHome    29950 non-null  float64
#  6   Education           29950 non-null  Int32
#  7   EducationField      29950 non-null  category
#  8   Gender              29950 non-null  category
#  9   JobLevel            29950 non-null  Int32
#  10  JobRole             29950 non-null  category
#  11  MaritalStatus       29950 non-null  category
#  12  MonthlyIncome       29950 non-null  float64
#  13  NumCompaniesWorked  29950 non-null  Int32
#  14  OverTime            29950 non-null  category
# ...

# %%
df.describe()
# Out:
#          EmployeeID        Age  DistanceFromHome  Education  JobLevel  \
# count       29950.0    29950.0      29950.000000    29950.0   29950.0
# mean   15000.265643  38.477963         15.030518   2.494023   3.00177
# std     8661.096956  12.046396          8.363830   1.115795  1.409826
# min             1.0       18.0          1.000000        1.0       1.0
# 25%         7499.25       28.0          8.000000        1.0       2.0
# 50%         15000.5       38.0         15.000000        2.0       3.0
# 75%        22500.75       49.0         22.000000        3.0       4.0
# max         30000.0       59.0         29.000000        4.0       5.0
#
#        MonthlyIncome  NumCompaniesWorked  YearsAtCompany
# count   29950.000000             29950.0    29950.000000
# mean    16049.531619            4.489249       19.593088
# std      8078.272672            2.861454       11.560741
# min      2000.000000                 0.0        0.000000
# ...

# %%
df.describe(include='category')
# Out:
#        Attrition BusinessTravel Department EducationField Gender  JobRole  \
# count      29950          29950      29950          29950  29950    29950
# unique         2              3          3              5      2        6
# top           No  Travel_Rarely      Sales      Technical   Male  Analyst
# freq       15101          10071      10100           6027  15017     5057
#
#        MaritalStatus OverTime
# count          29950    29950
# unique             3        2
# top         Divorced      Yes
# freq           10034    15108

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     15101
# Yes    14849
# Name: count, dtype: int64

# %%
df['Attrition'].value_counts(normalize=True)*100
# Out:
# Attrition
# No     50.420701
# Yes    49.579299
# Name: proportion, dtype: float64

# %%
df['Age'].describe()
# Out:
# count      29950.0
# mean     38.477963
# std      12.046396
# min           18.0
# 25%           28.0
# 50%           38.0
# 75%           49.0
# max           59.0
# Name: Age, dtype: Float64

# %%
df['MonthlyIncome'].describe()
# Out:
# count    29950.000000
# mean     16049.531619
# std       8078.272672
# min       2000.000000
# 25%       9056.250000
# 50%      16111.000000
# 75%      23008.750000
# max      29999.000000
# Name: MonthlyIncome, dtype: float64

# %%
df['YearsAtCompany'].describe()
# Out:
# count    29950.000000
# mean        19.593088
# std         11.560741
# min          0.000000
# 25%         10.000000
# 50%         20.000000
# 75%         30.000000
# max         39.000000
# Name: YearsAtCompany, dtype: float64

# %%
df.groupby('Gender')['Attrition'].value_counts(normalize=True)*100
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\3208784316.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Gender')['Attrition'].value_counts(normalize=True)*100
# Gender  Attrition
# Female  No           50.364964
#         Yes          49.635036
# Male    No           50.476127
#         Yes          49.523873
# Name: proportion, dtype: float64

# %%
df.groupby('Department')['Attrition'].value_counts(normalize=True)*100
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\2981788469.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Department')['Attrition'].value_counts(normalize=True)*100
# Department   Attrition
# Development  No           50.020056
#              Yes          49.979944
# HR           No           50.192347
#              Yes          49.807653
# Sales        No           51.039604
#              Yes          48.960396
# Name: proportion, dtype: float64

# %%
df.groupby('JobRole')['Attrition'].value_counts(normalize=True)*True
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\2422274046.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('JobRole')['Attrition'].value_counts(normalize=True)*True
# JobRole               Attrition
# Analyst               No           0.501483
#                       Yes          0.498517
# Developer             No           0.500199
#                       Yes          0.499801
# Executive             No           0.511048
#                       Yes          0.488952
# Manager               No           0.500799
#                       Yes          0.499201
# Research Scientist    No           0.507739
#                       Yes          0.492261
# Sales Representative  No           0.504139
#                       Yes          0.495861
# Name: proportion, dtype: float64

# %%
df.groupby('JobLevel')['Attrition'].value_counts(normalize=True)*100
# Out:
# JobLevel  Attrition
# 1         Yes          50.816049
#           No           49.183951
# 2         No           51.438379
#           Yes          48.561621
# 3         No           50.183701
#           Yes          49.816299
# 4         No           50.175321
#           Yes          49.824679
# 5         No           51.079859
#           Yes          48.920141
# Name: proportion, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                     EmployeeID       Age  DistanceFromHome  Education  \
# EmployeeID            1.000000  0.000559          0.004441   0.008543
# Age                   0.000559  1.000000          0.003449   0.011164
# DistanceFromHome      0.004441  0.003449          1.000000   0.003923
# Education             0.008543  0.011164          0.003923   1.000000
# JobLevel             -0.001502 -0.000604          0.005599  -0.008600
# MonthlyIncome        -0.005140  0.004863         -0.003261   0.010045
# NumCompaniesWorked    0.006464 -0.001366          0.001049  -0.000261
# YearsAtCompany       -0.000605  0.008211          0.001882   0.001376
#
#                     JobLevel  MonthlyIncome  NumCompaniesWorked  \
# EmployeeID         -0.001502      -0.005140            0.006464
# Age                -0.000604       0.004863           -0.001366
# DistanceFromHome    0.005599      -0.003261            0.001049
# Education          -0.008600       0.010045           -0.000261
# ...

# %%
df[df['MonthlyIncome']>df['MonthlyIncome'].quantile(0.99)]
# Out:
#        EmployeeID  Age Attrition     BusinessTravel Department  \
# 47          24789   39       Yes  Travel_Frequently         HR
# 205         16084   18       Yes      Travel_Rarely      Sales
# 379          5679   29       Yes  Travel_Frequently      Sales
# 512         29926   27        No      Travel_Rarely      Sales
# 574         19148   38        No  Travel_Frequently         HR
# ...           ...  ...       ...                ...        ...
# 29805        3628   55        No         Non-Travel         HR
# 29821        1060   58       Yes         Non-Travel         HR
# 29853       20225   31        No      Travel_Rarely      Sales
# 29856        8111   45       Yes      Travel_Rarely         HR
# 29925        5676   32       Yes         Non-Travel      Sales
#
#        DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 47                 15.0          3  Life Sciences  Female         3
# 205                18.0          3      Technical    Male         5
# ...

# %%
df[df['Age']>df['Age'].quantile(0.99)]
# Out:
# Empty DataFrame
# Columns: [EmployeeID, Age, Attrition, BusinessTravel, Department, DistanceFromHome, Education, EducationField, Gender, JobLevel, JobRole, MaritalStatus, MonthlyIncome, NumCompaniesWorked, OverTime, YearsAtCompany]
# Index: []

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
sns.set(font_scale=1.1)

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Attrition',color='yellow')
plt.title("Attrition Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df,x='Gender',hue='Attrition')
plt.title("Attrition by Gender")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x='Department',hue='Attrition',color='red')
plt.title("Attrition by Department")
plt.xticks(rotation=25)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9736\3743657497.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.countplot(data=df,x='Department',hue='Attrition',color='red')

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df, x='JobRole', hue='Attrition')
plt.title("Attrition by Job Role")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['MonthlyIncome'], kde=True,color='orange')
plt.title("Monthly Income Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['YearsAtCompany'],kde=True,color='blue')
plt.title("years at company Disribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['MonthlyIncome'],color='green')
plt.title("Monthly Income - Outlier Check")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=df, x='Attrition', y='MonthlyIncome',color='pink')
plt.title("Monthly Income vs Attrition")
plt.show()

# %%
df.to_csv("HR_Analytics_Cleaned.csv",index=False)

# %%
file_path ="HR_Analytics_Cleaned.csv"
df.to_csv(file_path, index=False)

print("File saved at:", file_path)
# Out:
# File saved at: HR_Analytics_Cleaned.csv
